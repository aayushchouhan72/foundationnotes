# %%
from reportlab.pdfgen import canvas as c

# %%
c
# Out:
# <module 'reportlab.pdfgen.canvas' from 'c:\\Users\\ASUS\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\reportlab\\pdfgen\\canvas.py'>

# %%
c.Canvas()

# %%
pdf = c.Canvas('new.pdf')

# %%
pdf

# %%
pdf.drawAlignedString(100,700,"Hello Python")

# %%
pdf.save()
