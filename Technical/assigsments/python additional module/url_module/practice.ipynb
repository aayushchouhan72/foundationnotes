# %%
from urllib.parse import urlparse
from rich import print

url ="https://docs.langchain.com/oss/python/langchain/overview"

result =  urlparse(url)

print(result)
# Out:
# ParseResult(
#     scheme='https',
#     netloc='docs.langchain.com',
#     path='/oss/python/langchain/overview',
#     params='',
#     query='',
#     fragment=''
# )

# %%
from urllib.parse import urlparse

url =  'https://docs.langchain.com/oss/python/langchain/overview'

x= urlparse(url)

print(x.scheme)
print(x.netloc)
print(x.path)
print(x.query)
# Out:
# https
# docs.langchain.com
# /oss/python/langchain/overview
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
from urllib.parse import urlsplit,urlunparse

x=urlsplit(url)

# %%
x
# Out:
# SplitResult(scheme='https', netloc='docs.langchain.com', path='/oss/python/langchain/overview', query='', fragment='')

# %%
print(x)
# Out:
# SplitResult(
#     scheme='https',
#     netloc='docs.langchain.com',
#     path='/oss/python/langchain/overview',
#     query='',
#     fragment=''
# )

# %%
url = urlunparse((
    'https',
    'docs.langchain.com',
    '/oss/python/langchain/overview',
    '',
    '',
    ""
))

# %%
print(url)
# Out:
# https://docs.langchain.com/oss/python/langchain/overview

# %%
from urllib.parse import urljoin,quote

base ="https://example.com/product/"

result =urljoin(base,'laptop')
print(result)
# Out:
# https://example.com/product/laptop

# %%
text = "hello  world'"
result =  quote(text)
print(result)
# Out:
# hello%20%20world%27

# %%
from urllib.parse import unquote

text =  "hello%20world"
print(unquote(text))
# Out:
# hello world
