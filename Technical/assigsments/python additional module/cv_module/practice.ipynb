# %%
import cv2 as c

# %%
image=c.imread('image.ipg')

# %%
print(image)
# Out:
# None

# %%
image = c.imread("image.jpg")

# %%
c.imshow("My Photo",image)

# %%
c.waitKey(0)
# Out:
# 0

# %%
c.destroyAllWindows()
