# %%
import uuid as u

# %%
id =  u.uuid1()
id
# Out:
# UUID('16075896-b134-11f1-8f20-505a654f94de')

# %%
id
# Out:
# UUID('16075896-b134-11f1-8f20-505a654f94de')

# %%
u.uuid4()
# Out:
# UUID('b5c16dd8-9033-4093-8c44-4709ce08a970')
