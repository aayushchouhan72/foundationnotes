# %%
import ipaddress as it

# %%
ip =  ipaddress.ip_address("192.168.1.10")

# %%
ip
# Out:
# IPv4Address('192.168.1.10')

# %%
type(ip)
# Out:
# ipaddress.IPv4Address

# %%
ip = ip.ip_address("2001:db8::1" )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 ip = ip.ip_address("2001:db8::1" )
#
# AttributeError: 'IPv4Address' object has no attribute 'ip_address'

# %%
ip
# Out:
# IPv4Address('192.168.1.10')

# %%
it.ip_network("192.168.1.0/24")
# Out:
# IPv4Network('192.168.1.0/24')

# %%
it.ip_interface("192.168.1.10/24")
# Out:
# IPv4Interface('192.168.1.10/24')

# %%
ip =  it.ip_address("192.168.1.10")

ip.version
# Out:
# 4
