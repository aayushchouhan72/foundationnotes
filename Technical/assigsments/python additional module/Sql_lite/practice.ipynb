# %%
import sqlite3 as s

# %%
con =  s.connect("student.db")

# %%
cur =  con.cursor()

# %%
cur.execute('''
CREATE TABLE student (
     id INTEGER ,
    name TEXT,
    age INTEGER

)

''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 cur.execute('''
#       2 CREATE TABLE student (
#       3      id INTEGER ,
#       4     name TEXT,
#       5     age INTEGER
#       6
#       7 )
#       8
#       9 ''')
#
# OperationalError: table student already exists

# %%
con.commit()

# %%
cur.execute("""
CREATE TABLE IF NOT EXISTS employe (
id INTEGER,
name TEXT,
age INTEGER
)


""")

# %%
cur.execute('''
INSERT INTO student VAlUES (2,'kommii',21)

''')

# %%
con.commit()

# %%
name = "Aayush"
age=  24

cur.execute(
    '''Insert into student (name,age) values (?,?)''',(name,age)
)

# %%
con.commit()

# %%
cur.execute("Select * from student ")

# %%
cur.fetchmany(1)
# Out:
# []

# %%
cur.execute(
    '''update student set age = ? where id= ?''',
    (25,1)
)

# %%
con.commit()
