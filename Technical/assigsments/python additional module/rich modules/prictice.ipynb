# %%
import rich

# %%
from rich import print 
print("[bold red ] Aayush !![/bold red ]")
print("[italic  ] Aayush !![/italic]")
# Out:
#  Aayush !!
#  Aayush !!

# %% [markdown]
# # Print()

# %%
print("[bold]Bold Text[/bold]")
print("[italic]Italic Text[/italic]")
print("[green]Success[/green]")
print("[red]Error[/red]")
print("[yellow]Warning[/yellow]")
# Out:
# Bold Text
# Italic Text
# Success
# Error
# Warning

# %% [markdown]
# ## Console() Funtion

# %%
from rich.console import Console

console =  Console()   # create and console object 

console.print("Hello world")
# Out:
# Hello world

# %% [markdown]
# # console.print()

# %%
console = Console()

console.print("[bold green] How are you Aayush !![/bold green ]")

console.print("Aayush how are you ...",style="yellow")
# Out:
#  How are you Aayush !!
# Aayush how are you ...

# %% [markdown]
# # 4 console.log()

# %%
from rich.console import Console


console = Console()

console.log("User Logged in ")
# Out:
# [14:37:33] User Logged in                                                                           ]8;id=2285720;file://C:\Users\ASUS\AppData\Local\Temp\ipykernel_6432\1888082015.py\1888082015.py]8;;\:]8;id=2285721;file://C:\Users\ASUS\AppData\Local\Temp\ipykernel_6432\1888082015.py#6\6]8;;\

# %%
from rich.console import Console

c= Console()

name = c.input("[bold red ] Enter the name :-[/bold red ]")

c.print(f"[bold orange] Hello {name}[/bold orange]")
# Out:
#  Enter the name :-
#  Hello Aayush

# %%
from rich.console import Console

c= Console()

c.rule("[bold red ]Student Information ...[/bold red]",style="yellow")
c.rule()
# Out:
# ───────────────────────────────────────────── Student Information ... ─────────────────────────────────────────────
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
from rich.console import Console
c= Console()

c.rule("[bold red ]Student Information ...[/bold red]",style="yellow")
c.rule()

c.clear()
# Out:
# ───────────────────────────────────────────── Student Information ... ─────────────────────────────────────────────
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ## console.status()

# %%
from rich.console import Console
import time

console = Console()

with console.status("Processing ..."):
    time.sleep(5)

console.print("Done!")
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Done!

# %% [markdown]
# ## console.print_exception()

# %%
from rich.console import Console

console=Console()

try:
     x=10/0
except:
     console.print_exception()
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:6                                                                                    │
# │                                                                                                  │
# │    3 console=Console()                                                                           │
# │    4                                                                                             │
# │    5 try:                                                                                        │
# │ ❱  6 │    x=10/0                                                                                 │
# │    7 except:                                                                                     │
# │    8 │    console.print_exception()                                                              │
# ...

# %% [markdown]
# # console.size

# %%
from rich.console import Console

console =  Console()

print(console.size)
# Out:
# ConsoleDimensions(width=115, height=100)

# %%
from rich.console import Console
from rich.panel import Panel

console = Console()

panel = Panel("Hello World")

console.print(panel)
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Hello World                                                                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
panel = Panel(
    "Welcome to Python",
    title="Message"
)

console.print(panel)
# Out:
# ╭──────────────────────────────────────────────────── Message ────────────────────────────────────────────────────╮
# │ Welcome to Python                                                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
from rich.console import Console
from rich.table import Table

console = Console()

table = Table()

table.add_column("Name")
table.add_column("Age")
table.add_column("City")

table.add_row("Ayush", "25", "Bhopal")
table.add_row("Rahul", "24", "Indore")

console.print(table)
# Out:
# ┏━━━━━━━┳━━━━━┳━━━━━━━━┓
# ┃ Name  ┃ Age ┃ City   ┃
# ┡━━━━━━━╇━━━━━╇━━━━━━━━┩
# │ Ayush │ 25  │ Bhopal │
# │ Rahul │ 24  │ Indore │
# └───────┴─────┴────────┘

# %%
from rich.progress import track
import time

for i in track(range(10), description="Processing..."):
    time.sleep(0.5)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
from rich.progress import track
import time

for item in track(range(20)):
    time.sleep(0.1)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
