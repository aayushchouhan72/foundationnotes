# %%
print("Hello World")
# Out:
# Hello World

# %%
from rich import print

print("[bold red]Hello World[/bold red]")
# Out:
# Hello World

# %%
from rich.console import Console

console = Console()

console.print("[bold green]Patient added successfully![/bold green]")
console.print("[yellow]Patient ID:[/yellow] 101")
console.print("[cyan]Name:[/cyan] Rahul")
console.print("[red bold]Hii [/red bold] ")
# Out:
# Patient added successfully!
# Patient ID: 101
# Name: Rahul
# Hii
